# %% [markdown]
# 1. Preamble
#
# This is a practice project for classification. I will analyze 5 datasets from Kaggle.
#
# Data Scientist Job Market in the U.S.: https://www.kaggle.com/sl6149/data-scientist-job-market-in-the-us
#
# Credit Approval Data Set: https://www.kaggle.com/anikannal/solar-power-generation-data
#
# Solar Power Generation Data: https://www.kaggle.com/anikannal/solar-power-generation-data
#
# Brazilian E-Commerce Public Dataset by Olist: https://www.kaggle.com/olistbr/brazilian-ecommerce
#
# Classify gestures by reading muscle activity: https://www.kaggle.com/kyr7plus/emg-4
#
#
# The initial approach is:
#
# a) import the databases
#
#     i) check for all paramenters required to get the file properly loaded
#
# b) table cleansing:
#
#     i) adjust columns headers and indexes
#     ii) evaluate table completeness (NaN, field types, etc)
#
# c) Numerical columns:
#
#     i) quick statistical analysis (descriptive statistics) of the columns (range - minimum and maximum, mean, standard deviation, median, mode)
#     ii) graphical evaluation (whisker box-plot and histograms)
#
# d) Categorical columns:
#
#     i) sort uniques to check for mispelling or variations of equivalent values
#     ii) count of distinct values
#     iii) graphical representation of the counts
#
# e) Initial exploration
#
#     i) scatterplot of each parameter versus the expected classification
#
# Let's start!!!

# %%
# Default libraries: pandas, numpy
import pandas as pd
import numpy as np

import math

# Load collections of functions
from matplotlib import pyplot as plt
from collections import Counter
from datetime import datetime

# %% [markdown]
# Data Scientist Job Market in the U.S.: https://www.kaggle.com/sl6149/data-scientist-job-market-in-the-us
#
# Context
# For those who are actively looking for data scientist jobs in the U.S., the best news this month is the LinkedIn Workforce Report August 2018. According to the report, there is a shortage of 151,717 people with data science skills, with particularly acute shortages in New York City, San Francisco Bay Area and Los Angeles.
#
# To help job hunters (including me) to better understand the job market, I scraped Indeed website and collected information of 7,000 data scientist jobs around the U.S. on August 3rd. The information that I collected are: Company Name, Position Name, Location, Job Description, and Number of Reviews of the Company.
#
# Content
# alldata.csv If you want to explore the job market around the U.S., download this one because it aggregates all information and cleans the job description by removing the tags.
# all other files. If you want to explore specific city or region, you can download any of them.
# Acknowledgements
# Special thanks to Indeed for not blocking me : )
#
# Inspiration
# If you have no clue of where to start, check my blog for inspiration.
# Link to my PowerPoint Slides for Presentation.
# Link to my GitHub Code.
# Reach me at sl6149@nyu.edu
# Possible Questions:
#
# Who gets hired? What kind of talent do employers want when they are hiring a data scientist?
# Which location has the most opportunities?
# What skills, tools, degrees or majors do employers want the most for data scientists?
# What's the difference between data scientist, data engineer and data analyst?
# Can you develop an efficient classification algorithm to differentiate the three job types above?

# %%
# import sys
# print(sys.path)

# %%
# A. IMPORT DATA - alldata.csv
main_path = 'C:\\Users\\map_f\\OneDrive\\Documents\\Dropbox\\Springboard\\Project\\Preet\\'
project_path = 'DS_market\\'
file_name = 'alldata.csv'

path = main_path + project_path
file = path + file_name

# parser = TextFileReader(fp_or_buf, **kwds)
raw_data = pd.read_csv(file,index_col= None,delimiter=',')
# type(raw_data)

# %%
# B. DATA "CLEANSING"
raw_data.shape
# Out:
# (6964, 5)

# %% [markdown]
# Data has 6964 entries and 5 columns.

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6964 entries, 0 to 6963
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     6953 non-null   object
#  1   company      6953 non-null   object
#  2   description  6953 non-null   object
#  3   reviews      5326 non-null   float64
#  4   location     6953 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 272.2+ KB

# %% [markdown]
# Observing the count of Non-Null entries in the data we can notice that reviews column has null values.
# The 5 columns are: position, company, description, reviews, and location. These column names seem reasonable but we can evaluate it better taking a quick look into the data.
#
# Dtype is aligned to the columns name meaning.

# %%
raw_data.head(10)
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
# 5                        Manager of Data Engineering  McKinsey & Company
# 6       Product Specialist - Periscope, New Ventures  McKinsey & Company
# 7  Junior to Mid-level Engineer, Geologist or Env...                Wood
# 8                      Analyst - CIB Credit Research            SunTrust
# 9  Senior Associate - Cognitive Data Scientist Na...                KPMG
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# 1  Job Description\n\n"The road that leads to acc...      NaN
# 2  Growing company located in the Atlanta, GA are...      NaN
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4  DESCRIPTION\nThe Emory University Department o...    550.0
# 5  Qualifications\nBachelor’s degree in Computer ...    385.0
# 6  Qualifications\nBachelor’s degree\n5-7 years o...    385.0
# 7  Overview / Responsibilities\nWood Environment ...    899.0
# 8  Works closely with senior CIB professionals. P...   3343.0
# 9  Known for being a great place to work and buil...   4494.0
#
#              location
# 0  Atlanta, GA 30301
# 1         Atlanta, GA
# 2         Atlanta, GA
# 3  Atlanta, GA 30303
# 4         Atlanta, GA
# 5  Atlanta, GA 30318
# 6  Atlanta, GA 30318
# 7         Atlanta, GA
# 8         Atlanta, GA
# 9   Atlanta, GA 30338

# %% [markdown]
# Position is the position name, as well as company is the company name, description is the job description, reviews is a count of how many reviews that company had with some NaN as mentioned before, and location shows City, State, and Zip Code. Location is an incomplete field so for a more accurate analysis of geographical location we will need to split it into the 3 fields.
#
# Data type is adequated to the fields we are presenting.

# %%
# C. Numerical columns
raw_data['reviews'].describe()
# Out:
# count      5326.000000
# mean       3179.089185
# std        8448.515056
# min           2.000000
# 25%          27.000000
# 50%         230.000000
# 75%        1578.000000
# max      148114.000000
# Name: reviews, dtype: float64

# %%
plt.clf
plt.boxplot(raw_data['reviews'].dropna())
plt.show()

# %%
raw_data['reviews'].hist(bins=int(math.sqrt(raw_data['reviews'].count()))) # "ideal" bin size: sqrt(N)
# Out:
# <AxesSubplot:>

# %%
# reviews
lst = raw_data['reviews']
data = Counter(lst)
data.most_common(1)  # Returns the highest occurring item
# Out:
# [(25902.0, 224)]

# %% [markdown]
# The average 3k reviews are number inflated by the mode 26k. The most of values are close to zero. So any analysis relying on reviews average won't be significative.

# %%
# D. Categorical

# %%
uniques = list()
uniques = list(set(raw_data['position']))
# uniques = uniques.sort()
print(uniques)
# Out:
# [nan, 'Bioinformatics Scientist (CA)', 'Data Scientist Lead - Global Research & Data Analytics - ED', 'Program/Project Coordinator Opportunity - This is not a Technical IT role, but rather a support role for data analysis, system updates and reporting.', 'Human Resources Specialist or Human Resources Advisor', 'Optical Technician III (663385)', 'Software Development Engineer, Developer Infrastructure', 'Research Assistant', 'Senior Data Scientist I – Bioinformatics Developer', 'Technician II-Test (660965) - Security Clearance Required', 'Personal Financial Management - Chief Data Scientist - Vice President - New York City', 'Learning and Development Coordinator', 'Pricing & Promotions Data Scientist', 'Senior Scientist II, Quality Technical Operations', 'Telemetry Tracking & Command/Communications Project Engineer II (662650) - Security clearance requir', 'Data Scientist, Digital', 'Data Scientist/Software Engineer', 'Construction Materials and Geotechnical Testing Laboratory Technician', 'Sr. Vulnerability Management Engineer', 'Associate Principal Operations Research Scientist', 'Tools & Application Software Engineer', 'TECHNICAL RESEARCH ASSISTANT/40 HOURS/DAY/BWH- RESEARCH PATH', 'Senior Grants Specialist', 'Master Data Engineer', 'Scientist I/II', 'Senior Automation Test Engineer (Front End)', 'Computer Vision & Machine Learning Engineer', 'Scientist II, PK/PD and PBPK Modeling', 'Sr Data Scientist UW', 'Senior Engineer - Space Systems (660320)', 'Mgr/Sr Mgr-Model Risk Management - Data Scientist', 'Data Scientist- Clearance Required', 'HIV Research Scientist', 'Scientist: Human Machine Interface Researcher', 'Data Engineering Lead', 'Sub', 'Scientist, Platform Development', 'Data Engineer, Various Data Engineering Teams', 'Data Scientist, Multi-Channel Acquisition', 'Scientist, Process & Analytical Development, Cell Therapy', 'Lead Operations Research Scientist', 'Senior Applied Scientist-Alexa Deep Learning', 'Director of Analytics / Data Mining', 'Staff Scientist, Polymer and Surface Chemistry', 'Principal Data Scientist(Clinical Data/EMR/NLP/Deep Learning)-PS10509', 'Computational Scientist', 'Video Development Editor', 'Data Scientist, Algorithms', 'Data Scientist - Inference', 'Software Development Engineer, Personalization', 'Java Engineer (Machine Learning)', 'ANALYST, PROGRAM RESEARCH', 'Environmental Remediation Scientist', 'Data Scientist, Premium Analytics', 'Research Scientist (Vision Technology)', 'Applied Scientist - Machine Learning', 'Research Associate, IVD', 'Field Application Scientist II', 'Serve Jersey City - Community Research Analyst', 'Seasonal Environmental Compliance Monitor and Arborist', 'Quantitative Researcher - AI and Machine Learning Specialist', 'Professional Research Asst', 'Senior Data Architect', 'Research Staff Member, AI Learning', 'Infrastructure Engineer', 'Organizational Research Analyst', 'Research Data Analyst/Senior Statistician', 'JP Morgan Chase Institute- Research Analyst for Financial Markets', 'Scientist III, Chemistry, Mfg & Cntrl', 'Data Scientist PhD', 'Business Operations Analyst', 'Research Associate (Cell Culture Technician)', 'Senior Data Scientist, Alexa AI', 'Marketing Information Analytics Coordinator', 'Science Scientist - BioPhysics', 'Medical Director, Neurology', 'Staff Scientist, Immunotherapy', 'POSTDOCTORAL SCIENTIST, PHENOMICS', 'Research Position (Various Levels), Neuroscience', 'Executive Operations Research Analyst-Must have Clearance', 'Junior Statistical Programmer', 'Senior Software Development Manager, Alexa Artificial Intelligence', 'Python Software Engineer (IoT)', 'Director of Product Management', 'Immunology Lab Head', 'Data Scientist Analyst JG18', 'RESEARCH ASSOCIATE, T CELL IMMUNOLOGY', 'Finance & Data Analyst', 'Director of Data Acquisition', 'Senior Scientist - Machine Learning & Probabilistic Modeling', 'Senior Quantitative Scientist', 'Data Analyst Disaster Recovery Implementation', 'Sr. Associate Scientist', 'Research Data Analyst Assoc ...

# %%
# position
lst = raw_data['position']
data = Counter(lst)
data.most_common()   # Returns all unique items and their counts
# Out:
# [('Data Scientist', 351),
#  ('Senior Data Scientist', 96),
#  ('Research Analyst', 64),
#  ('Data Engineer', 60),
#  ('Machine Learning Engineer', 56),
#  ('Lead Data Scientist', 31),
#  ('Research Scientist', 30),
#  ('Sr. Data Scientist', 28),
#  ('Principal Data Scientist', 24),
#  ('Data Analyst', 22),
#  ('Software Engineer', 22),
#  ('Quantitative Analyst', 21),
#  ('Scientist', 17),
#  ('Product Manager', 17),
#  ('Bioinformatics Scientist', 16),
#  ('Market Research Analyst', 15),
#  ('Senior Software Engineer', 14),
#  ('Machine Learning Scientist', 13),
#  ('Software Engineer, Machine Learning', 13),
#  ('Senior Research Analyst', 12),
#  ('Senior Data Engineer', 12),
#  (nan, 11),
#  ('Associate Scientist', 11),
#  ('Senior Scientist', 11),
#  ('Software Development Engineer', 11),
#  ('Staff Data Scientist', 11),
#  ('Lead Data Engineer', 9),
#  ('Research Associate', 9),
#  ('Student Research Collaboration', 9),
#  ('Sr. Data Engineer', 8),
#  ('Senior Machine Learning Engineer', 8),
#  ('Senior Machine Learning Scientist', 8),
#  ('Clinical Scientist', 8),
#  ('Senior Associate, Data Scientist', 7),
#  ('Senior Quantitative Analyst', 7),
#  ('Research Data Analyst', 7),
#  ('Director, Data Science', 7),
#  ('Business Analyst', 7),
#  ('Senior Software Development Engineer', 7),
#  ('Data Scientist, Analytics', 7),
#  ('Statistical Analyst', 6),
#  ('Director of Data Science', 6),
#  ('Staff Software Engineer', 6),
#  ('Data and Machine Learning Technical Trainer, Google Cloud Platform', 6),
#  ('Manager, Data Science', 6),
#  ('Computational Biologist', 6),
#  ('Principal Statistical Programmer', 6),
#  ('Research Assistant', 6),
#  ('Machine Learning Data Scientist', 6),
#  ('Senior Applied Scientist', 6),
#  ('Senior Data Analyst', 6),
#  ('International Research Analyst', 6),
#  ('Staff Scientist', 6),
#  ('Data Science Manager', 6),
#  ('Sales Engineer, Machine Learning, Google Cloud', 6),
#  ('Operations Research Analyst', 6),
#  ('Applied Scientist', 6),
#  ('Sr Data Scientist', 6),
#  ('Director, Data Scientist', 5),
#  ('Environmental Scientist', 5),
#  ('Director, NLP Data Scientist', 5),
#  ('Senior Associate, Data Scientist (NLP/AI)', 5),
#  ('Supply Chain Data Science Consultant', 5),
#  ('Supply Chain Data Science Manager', 5),
#  ('Software Engineer - Machine Learning', 5),
#  ('Senior Operations Research Analyst', 5),
#  ('Research Engineer', 5),
#  ('Statistician', 5),
#  ('Data Scientist I', 5),
#  ('Data Analysis Manager', 5),
#  ('Full Stack Engineer', 5),
#  ('Principal Software Engineer', 5),
#  ('Administrative Assistant', 5),
#  ('Junior Data Scientist', 5),
#  ('Quantitative Research Analyst', 5),
#  ('Senior Associate - Cognitive Data Scientist Natural Language Processing',
#   4),
#  ('Manager - Cognitive Data Scientist Natural Language Processing', 4),
#  ('Data Science Instructor', 4),
#  ('Principal Research Scientist', 4),
#  ('Associate Research Scientist', 4),
#  ('Commercial Construction Market Leader – Global Facilities', 4),
#  ('Research Associate II', 4),
#  ('Sales Development Representative', 4),
#  ('Clinical Research Scientist', 4),
#  ('Software Developer', 4),
#  ('Developer Advocate, Serverless', 4),
#  ('Research Technician', 4),
#  ('Language Engineer', 4),
#  ('Engineering Manager', 4),
#  ('GIS System Administrator', 4),
#  ('Sr. Research Analyst', 4),
#  ('Senior Research Scientist / Fellow I, Computational Genomics', 4),
#  ('Chief Data Scientist', 4),
#  ('Marketing Data Scientist', 4),
#  ('Associate Data Scientist', 4),
#  ('Data Scientist - Human Services', 4),
#  ('Senior Product Manager', 4),
#  ('Data Scientist II', 4),
#  ('Biostatistician', 4),
#  ('Deep Learning Scientist', 4),
#  ('Principal Scientist', 4),
#  ('Senior Research Scientist', 4),
#  ('Research Data Scientist', 4),
#  ('Research Scientist, Google Brain (United States)', 4),
#  ('Machine Learning Architect', 4),
#  ('Data Scientist, Engineering', 4),
#  ('Big Data Engineer', 4),
#  ('Software Engineer, Imaging', 4),
#  ('VP, Data Science', 4),
#  ('Data Visualization Engineer', 4),
#  ('Machine Learning', 4),
#  ('Sr. Machine Learning Engineer', 4),
#  ('Manager, Data Scientist', 3),
#  ('Azure Data Scientist, Manager', 3),
#  ('Director, Financial Services - Data Scientist', 3),
#  ('Research Scientist I', 3),
#  ('Quantitative Finance Analyst', 3),
#  ('Manager, Data Scientist (ML/NLP) -- Financial Services', 3),
#  ('Azure Data Scientist, Senior Associate', 3),
#  ('Senior Scientist, Content Science', 3),
#  ('Research Specialist', 3),
#  ('Senior Associate, Data Scientist/Statistics -- Financial Services', 3),
#  ('Senior Business Intelligence Analyst', 3),
#  ('Principal Engineer', 3),
#  ('Senior Sales Account Executive', 3),
#  ('Senior Market Research Analyst', 3),
#  ('Sr Quantitative Finance Analyst', 3),
#  ('Data Software Engineer', 3),
#  ('Senior Technical Writer', 3),
#  ('Data Science Engineer', 3),
#  ('Technical Writer', 3),
#  ('Sr. Product Manager', 3),
#  ('Statistical Programmer', 3),
#  ('Solutions Architect, Machine Learning, Google Cloud', 3),
#  ('Municipal Bond Research Analyst', 3),
#  ('Backend Engineer', 3),
#  ('Sr Scientist', 3),
#  ('Operations Research Scientist', 3),
#  ('Head of Data Science', 3),
#  ('Immunologist', 3),
#  ('UX Designer', 3),
#  ('Research Fellow', 3),
#  ('Principal Machine Learning Engineer', 3),
#  ('Associate Director, Statistical Programming', 3),
#  ('Clinical Research Coordinator', 3),
#  ('Technical Product Manager', 3),
#  ('Senior Statistical Analyst', 3),
#  ('Solution Architect', 3),
#  ('Data Scientist (Product)', 3),
#  ('Computational Scientist', 3),
#  ('Senior Front End Engineer', 3),
#  ('DATA SCIENTIST', 3),
#  ('Sr. Software Engineer', 3),
#  ('DevOps Engineer', 3),
#  ('Senior Statistical Programmer', 3),
#  ('Research & Data Analyst', 3),
#  ('Analyst', 3),
#  ('Senior Research Associate', 3),
#  ('Senior Data & Applied Scientist', 3),
#  ('Manager, Machine Learning', 3),
#  ('Senior Data Science Engineer', 3),
#  ('Data Scientist/Quantitative Analyst Intern, Summer 2018', 3),
#  ('Product Data Scientist', 3),
#  ('Product Analyst, Data Science', 3),
#  ('Research Scientist, Machine Learning and Intelligence', 3),
#  ('MSAT Scientist', 3),
#  ('Data & Applied Scientist', 3),
#  ('Bioinformatics Scientist / Data Scientist', 3),
#  ('DATA ENGINEER', 3),
#  ('Sr Software Engineer', 3),
#  ('Assistant Staff Scientist', 3),
#  ('Mechanical Design Engineer', 3),
#  ('Software Development Manager', 3),
#  ('Applied Scientist - Alexa Engine', 3),
#  ('Developer Programs Engineer, Machine Learning', 3),
#  ('Senior Electrical Engineer', 2),
#  ('Health Scientist', 2),
#  ('Lead Decision Scientist', 2),
#  ('Scientist, Asst (AR) SOM', 2),
#  ('Regulatory Labeling, Advertising and Promotion Scientist', 2),
#  ('Business Intelligence Engineer', 2),
#  ('Director, Data Scientist -- Financial Services/Insurance', 2),
#  ('Data Visualization Software Engineer', 2),
#  ('Big Data SW Engineer', 2),
#  ('Senior Scientist, Advertising', 2),
#  ('Full Stack Developer', 2),
#  ('Director, Data Science (PS6695)', 2),
#  ('Entry-Level Electrical Engineer', 2),
#  ('Sr Staff Software Engineer', 2),
#  ('Jr. Data Scientist', 2),
#  ('Account Executive - Atlanta', 2),
#  ('Front End Engineer', 2),
#  ('Sr. Market Research Analyst', 2),
#  ('Senior Machine Learning Research Scientist', 2),
#  ('Food Scientist', 2),
#  ('Quantitative Data Analyst', 2),
#  ('Recruiter', 2),
#  ('Test Technician 1', 2),
#  ('Sr. Research Scientist', 2),
#  ('Research Analyst - Advanced Analytics', 2),
#  ('Project Analyst', 2),
#  ('Quantitative Marketing Analyst', 2),
#  ('Machine Learning Research Scientist', 2),
#  ('Sales Engineer', 2),
#  ('Senior Consultant, Advanced Analytics', 2),
#  ('Email Marketing Manager', 2),
#  ('Marketing Operations Director 5', 2),
#  ('Senior Director, Data Science', 2),
#  ('Software Engineer III', 2),
#  ('Data Management Specialist', 2),
#  ('Scientist I/II - Bioinformatics', 2),
#  ('Senior Research Associate, Immunology', 2),
#  ('Senior Developer', 2),
#  ('RESEARCH ANALYST', 2),
#  ('Senior Analyst, Data and Analysis', 2),
#  ('RESEARCH SCIENTIST', 2),
#  ('Data Science Specialist', 2),
#  ('Sr. Vice President, Data Analytics', 2),
#  ('Senior Data Analytics Expert', 2),
#  ('Machine Learning/NLP Engineer', 2),
#  ('Quantitative Researcher- Machine Learning', 2),
#  ('Biostatistician I', 2),
#  ('Research Scientist Parallel Medicinal Chemistry', 2),
#  ('Scientist, Pharmacology', 2),
#  ('Research Scientist Functional Genomics', 2),
#  ('Associate Director, Lead Data Scientist', 2),
#  ('Research Analyst III', 2),
#  ('Field Application Scientist (Pre-Sales)', 2),
#  ('Research Scientist Discovery Biology', 2),
#  ('Senior Scientist Chemical and Materials Engineering', 2),
#  ('Senior Scientist Analytical Development', 2),
#  ('Senior Machine Learning / Artificial Intelligence Engineer', 2),
#  ('Principal, Education | Science | Tech', 2),
#  ('Software Product Manager', 2),
#  ('Principal Product Manager Technical, Amazon Search (L7)', 2),
#  ('Senior HR Manager', 2),
#  ('Senior Software Developer', 2),
#  ('TECHNICAL RESEARCH ASSISTANT II / DAY / 40 HOURS / BWH NEUROLOGY', 2),
#  ('TECHNICAL RESEARCH ASSISTANT I / 40 HOUR / DAY / BWH - INFECTIOUS DISEASES',
#   2),
#  ('Market Research Manager', 2),
#  ('Senior Medical Writer', 2),
#  ('Principal Clinical Scientist', 2),
#  ('Senior Enterprise Software Engineer', 2),
#  ('Software Engineer - Human Machine Interface Design', 2),
#  ('Research Technologist, Sr.', 2),
#  ('Sales Manager', 2),
#  ('Scientist Formulation Development', 2),
#  ('Lead Research Analyst', 2),
#  ('Lead Operations Research Scientist', 2),
#  ('Automation Engineer', 2),
#  ('Senior Imaging Scientist', 2),
#  ('Senior Bioinformatics Scientist', 2),
#  ('Marketing Manager', 2),
#  ('Upstream Technology Principal Research Analyst, CERAWeek', 2),
#  ('Senior Product Designer', 2),
#  ('IDBS - Product Business Manager', 2),
#  ('Senior Manager, Data Science', 2),
#  ('QA Engineer', 2),
#  ('Research Scientist Reaction Optimization', 2),
#  ('Business Development Manager (NBA)', 2),
#  ('Computer Vision Research Scientist', 2),
#  ('Principal Machine Learning Scientist', 2),
#  ('Senior Data Engineer / Algo-Dev', 2),
#  ('Research Scientist Chemical Biology', 2),
#  ('Data Scientist, Advanced Analytics', 2),
#  ('Senior Data Scientist / Machine Learning', 2),
#  ('Customer Facing Data Scientist', 2),
#  ('Customer Data Scientist', 2),
#  ('Data Scientist / Quantitative Researcher, Systematic Trading', 2),
#  ('Principal Machine Learning Data Scientist - Natural Language Processing',
#   2),
#  ('D3- Sr. NLP Deep Learning Data Scientist', 2),
#  ('Senior Solution Architect', 2),
#  ('Data Scientist, Optimization', 2),
#  ('Scientist 1', 2),
#  ('Quantitative Researcher - Data Quality', 2),
#  ('Manager, Data Scientist (AI/NLP)', 2),
#  ('Variant Scientist', 2),
#  ('Associate/Scientist', 2),
#  ('Data Platform Engineer', 2),
#  ('Machine Learning Researcher', 2),
#  ('Staff Electrical Engineer', 2),
#  ('Artificial Intelligence Engineer, Senior Associate', 2),
#  ('Senior Research Analyst - Competitive Intelligence', 2),
#  ('Machine Learning Engineer, Manager', 2),
#  ('Cloud Ops Engineer', 2),
#  ('Director', 2),
#  ('Research Associate III', 2),
#  ('Technical Research Analyst - Cryptoassets', 2),
#  ('Postdoctoral Research Associate', 2),
#  ('Software Engineer, Backend (Multiple levels)', 2),
#  ('Director of Engineering', 2),
#  ('Sr Research Analyst', 2),
#  ('Program Assistant', 2),
#  ('Scientist III, Chemistry, Mfg & Cntrl', 2),
#  ('Planning Associate', 2),
#  ('Research Analyst I', 2),
#  ('Data Scientist / Sr. Data Scientist', 2),
#  ('Data and Policy Analyst - Statistical Programmer', 2),
#  ('OPERATIONS RESEARCH ANALYST', 2),
#  ('Research and Data Analyst', 2),
#  ('Toxicologist', 2),
#  ('Intelligence Research Analyst', 2),
#  ('SENIOR SOFTWARE ENGINEER', 2),
#  ('Facilities Manager', 2),
#  ('Vice President, DFIR', 2),
#  ('Project Scientist', 2),
#  ('Computer Scientist', 2),
#  ('Researcher', 2),
#  ('Director Data Science', 2),
#  ('Solutions Analyst', 2),
#  ('Senior Business Analyst', 2),
#  ('Presales Solutions Architect | Machine Learning', 2),
#  ('Associate, Client Success', 2),
#  ('Senior/Lead Software Developer - AMAZON ALEXA MACHINE LEARNING SCIENCE TEAM - Kendall Square/Cambridge, MA',
#   2),
#  ('Senior Scientist, Analytical Development', 2),
#  ('Product Designer', 2),
#  ('Sr. Statistical Programmer', 2),
#  ('Formulation Scientist', 2),
#  ('Research Associate I', 2),
#  ('Applied Scientist I', 2),
#  ('Product Analyst', 2),
#  ('Software Engineer - Data', 2),
#  ('Scientist, Cellular Immunology', 2),
#  ('Procurement Analyst', 2),
#  ('Senior Software Developer - AMAZON ALEXA Machine Learning Team - Cambridge, MA',
#   2),
#  ('Principal Program Manager', 2),
#  ('Sr. Machine Learning Manager- 2018 Alexa Boston', 2),
#  ('Senior Software Engineering Lead', 2),
#  ('Senior Software Developer - AMAZON ALEXA Machine Learning Science Team in Cambridge, MA',
#   2),
#  ('Senior Software Engineer - AMAZON ALEXA MACHINE LEARNING SCIENCE TEAM - Cambridge, Massachusetts',
#   2),
#  ('Director of Research Chemistry', 2),
#  ('Nonclinical Research Scientist/Senior Research Associate', 2),
#  ('Senior Scientist, Quality Control', 2),
#  ('Python Software Developer - AMAZON ALEXA Machine Learning Team in Cambridge, MA',
#   2),
#  ('Aerospace Machine Learning Group Lead', 2),
#  ('Director, Product Management', 2),
#  ('Senior Scientist, Vector Engineering', 2),
#  ('Pharmacometrician', 2),
#  ('Sr. Machine Learning Scientist, Amazon Alexa', 2),
#  ('Research Scientist- Alexa ML', 2),
#  ('Process Development Scientist', 2),
#  ('Sr. Scientist, Toxicology', 2),
#  ('Data Scientist Technical Lead, Engineering', 2),
#  ('People Scientist', 2),
#  ('Engineering Resident, University Graduate (Fixed-Term Employee)', 2),
#  ('Product Analytics Lead, Data Science', 2),
#  ('Software Engineer, ARCore', 2),
#  ('Sr. Software Engineer - Machine Learning', 2),
#  ('Sr Machine Learning Engineer', 2),
#  ('Principal Software Engineer (Search -Machine Learning)', 2),
#  ('Senior Software Engineer (Search Relevance/Infra)', 2),
#  ('Machine Learning Software Engineer', 2),
#  ('Program Manager', 2),
#  ('Data Scientist - Analytics', 2),
#  ('Data Scientist (NYC)', 2),
#  ('Experienced Data Scientist', 2),
#  ('Behavioral Scientist', 2),
#  ('Assistant Research Scientist', 2),
#  ('Clinical Data Scientist', 2),
#  ('Predictive Modeling Analyst', 2),
#  ('Director of Data', 2),
#  ('Machine Learning Infrastructure Engineer', 2),
#  ('Lead Data Science Instructor, Principal Data Scientist', 2),
#  ('Quality Control Scientist', 2),
#  ('Facility Budget Research Analyst', 2),
#  ('Technical Recruiter', 2),
#  ('Scientist, Analytical Sciences', 2),
#  ('Backend Developer', 2),
#  ('Big Data Architect', 2),
#  ('Policy Research Analyst', 2),
#  ('Scientist I', 2),
#  ('Research Analyst II', 2),
#  ('Cafe Recruiter', 2),
#  ('Research Coordinator', 2),
#  ('Financial Analyst', 2),
#  ('Field Application Scientist', 2),
#  ('Research Assistant I', 2),
#  ('Data Architect', 2),
#  ('Applied Research Scientist, Core Machine Learning', 2),
#  ('Research Scientist, Machine Learning (PhD University Grad)', 2),
#  ('Sr. Applied Scientist', 2),
#  ('Data Research Analyst', 2),
#  ('Computer Vision Data Scientist', 2),
#  ('Senior Data Architect', 2),
#  ('Software Development Engineer II', 2),
#  ('Research Scientist II, Electrophysiology', 2),
#  ('Bioinformatics Scientist 1', 2),
#  ('Temporary Research Scientist I, Electrophysiology', 2),
#  ('Scientist 1, Microbiology Development', 2),
#  ('Staff Controls Engineer', 2),
#  ('Staff Software Engineer/Architect', 2),
#  ('Data Driven Marketing Analytics Manager, Director', 2),
#  ('Staff Software Architect', 2),
#  ('Project Administrator/Project Accountant', 2),
#  ('High Throughput Screening Scientific Leader', 2),
#  ('Senior Machine Learning Architect', 2),
#  ('Pursuit Leader/Proposal Coordinator', 2),
#  ('Research Scientist - Deep Learning', 2),
#  ('Data Scientist, Fire TV Product Management', 2),
#  ('Data Scientist - Biostatistics', 2),
#  ('Sr. Software Development Engineer, Amazon SageMaker, AWS AmazonAI Machine Learning Platform',
#   2),
#  ('Principal Technical Program Manager', 2),
#  ('Software Development Engineer, Amazon SageMaker, AWS AmazonAI Machine Learning Platform',
#   2),
#  ('Software Development Engineer in Test', 2),
#  ('Software Development Engineer, Amazon SageMaker ML Frameworks, AWS AmazonAI Machine Learning Platform',
#   2),
#  ('Senior Software Engineer - Machine Learning', 2),
#  ('Sr. Technical Recruiter', 2),
#  ('Lead Machine Learning Engineer', 2),
#  ('Software Development Engineer, AWS Lex', 2),
#  ('Frontend/UI Engineer, Amazon SageMaker, AWS Machine Learning Platform', 2),
#  ('Frontend/UI Engineer, Amazon SageMaker, AWS AmazonAI Machine Learning Platform',
#   2),
#  ('Software Development Manager, Machine Learning', 2),
#  ('Customer Success Manager', 2),
#  ('Distinguished Software Engineer - Machine Learning', 2),
#  ('SDE AWS SageMaker Algorithms; Machine Learning; AI', 2),
#  ('Internal Auditor', 2),
#  ('Knowledge Engineer', 2),
#  ('Deep Learning Scientist - Yield Analytics', 2),
#  ('Data Scientist - Insurance', 2),
#  ('Data Scientist - Machine Learning', 2),
#  ('Principal Data Engineer', 2),
#  ('Global Safety Scientist', 2),
#  ('Application Scientist', 2),
#  ('Clinical Data Manager', 2),
#  ('Compensation Analyst', 2),
#  ('Senior/Principal Digital Health Platforms Data Scientist (PHC)', 2),
#  ('Forensic Toxicologist', 2),
#  ('Head of Data', 2),
#  ('Senior Data Scientist, Analytics', 2),
#  ('SENIOR DATA SCIENTIST', 2),
#  ('Manager, TPMs', 2),
#  ('Machine Learning Scientist, Amazon Alexa', 2),
#  ('Applied Machine Learning Scientist', 2),
#  ('Lead Data Scientist - Machine Learning', 2),
#  ('Research Analyst - Social and Customer Trends', 2),
#  ('Knowledge Engineer, Amazon Alexa', 2),
#  ('Sr Speech Scientist', 2),
#  ('Deep Learning Software Development Engineer', 2),
#  ('Sr. Hardware Audio Engineer', 2),
#  ('AI Research/Software Development Engineer, Alexa Artificial Intelligence',
#   2),
#  ('Sr. Technical Program Manager', 2),
#  ('Senior Research Engineer, Alexa', 2),
#  ('Data Scientist - Alexa Language Technologies', 2),
#  ('Data Scientist, Customer Interests & Personalization', 2),
#  ('Development Director', 1),
#  ('An Ostentatiously-Excitable Principal Research Assistant to Chief Scientist',
#   1),
#  ('Assistant Professor -TT - Signal Processing & Machine Learning', 1),
#  ('Manager of Data Engineering', 1),
#  ('Product Specialist - Periscope, New Ventures', 1),
#  ('Junior to Mid-level Engineer, Geologist or Environmental Scientist', 1),
#  ('Analyst - CIB Credit Research', 1),
#  ('STATISTICAL FORECAST ANALYST', 1),
#  ('Health Scientist III-CPTS', 1),
#  ('Assistant Scientist (AR) SOM', 1),
#  ('Business Intelligence Data Science Analyst - Supply Chain', 1),
#  ('Senior Structural Engineer-Transmission & Distribution', 1),
#  ('Senior Mobile Developer (iOS/Android)', 1),
#  ('Sr. Manager, Full Stack Development, KPMG Tax Ignition', 1),
#  ('DATA SCIENTIST - Supply Chain', 1),
#  ('Data Scientist, Keying & Linking', 1),
#  ('Data Scientist 1 – AP Forensics Team', 1),
#  ('Data Scientist - ICL', 1),
#  ('Data Scientist, Online', 1),
#  ('Data Scientist - CONSULTANT Level - ORLANDO FLORIDA - We will help Relocate',
#   1),
#  ('Business Intelligence Data Scientist - Supply Chain', 1),
#  ('Entry Level/Junior-Level Scientist', 1),
#  ('Scientist - Data Analysis', 1),
#  ('DATA SCIENTIST - SPACE OPTIMIZATION', 1),
#  ('Data Science Specialist - Periscope, New Ventures', 1),
#  ('Manager - Data Scientist ! Orlando!', 1),
#  ('Scientist II', 1),
#  ('Data Scientist - Consultant Level - Orlando, Florida - we will assist with relocation',
#   1),
#  ('Flight Safety Data Analysis Fall Co-Op', 1),
#  ('Chief Deep Learning Scientist', 1),
#  ('Supervisory Health Scientist', 1),
#  ('VP, Data Scientist- Atlanta, GA; Charlotte, NC', 1),
#  ('VP, Data Analytics', 1),
#  ('Scientist I - Sensory Panel Leader', 1),
#  ('Data Scientist or Data Scientist Lead PS10268', 1),
#  ('Senior Cyber Security Data Scientist', 1),
#  ('Scientist II/Ecologist II', 1),
#  ('Machine Learning / Artificial Intelligence Research Scientist', 1),
#  ('Statistical Quantitative Analyst', 1),
#  ('Scientist, Asst Bioinformatics', 1),
#  ('Analyst, Research', 1),
#  ('Information Technology Specialist', 1),
#  ('DATA ANALYST SUPPLY CHAIN', 1),
#  ('Health Communications Specialist', 1),
#  ('Data Engineer - GC Insights, New Ventures', 1),
#  ('Technical Evangelist – Database, Analytics, and Machine Learning', 1),
#  ('Sr Scientist II, Analytical Science', 1),
#  ('HIV Research Scientist', 1),
#  ('SI CoE IoT Data Modeling Architect', 1),
#  ('Associate Scientist, SOM', 1),
#  ('Data Engineer, Scala', 1),
#  ('Data & Analytics Developer', 1),
#  ('Product Development Scientist', 1),
#  ('Data Scientist - Senior Consultant - Orlando, Florida', 1),
#  ('Lead R & D Engineer/Scientist', 1),
#  ('Advertiser Research Analyst', 1),
#  ('Research Informatics Analyst', 1),
#  ('Enterprise Data Analyst & Data Engineer', 1),
#  ('Public Health Communications Specialist', 1),
#  ('Communications Specialist', 1),
#  ('2018 - Health Research Analyst 2 - New', 1),
#  ('Staff Research Scientist VII: Informational Interpretation Researcher', 1),
#  ('Scientist, Asst (AR) School Of Medicine (SOM)', 1),
#  ('Entry Level Geologist, Engineer or Environmental Scientist', 1),
#  ('Supervisory Epidemiologist', 1),
#  ('Quantitative Finance Analyst/C++ Developer', 1),
#  ('Jr Microbiologist - CDC', 1),
#  ('Coding Research Analyst', 1),
#  ('Data Science Manager- Atlanta', 1),
#  ('Business Intelligence Analyst, People Analytics & Measurement', 1),
#  ('Mid Data Scientist - Machine Learning', 1),
#  ('Vendor Research Analyst', 1),
#  ('Sponsored Research Financial Analyst', 1),
#  ('Director HR Data and Insights', 1),
#  ('BI Quantitative Analyst', 1),
#  ('Associate Product Designer', 1),
#  ('Ecologist', 1),
#  ('Tech Fall 2018 Intern - Machine Learning', 1),
#  ('R&D Innovation Engineer - Video Analytics/Machine Learning', 1),
#  ('Data Analytics Engineer / Big Data Engineer', 1),
#  ('Corporate Investment Quantitative Finance Analyst', 1),
#  ('Malware Analyst', 1),
#  ('Principal Research Scientist I: Informational Library Architect Extraordinaire',
#   1),
#  ('Manager, Statistical Modeling & Analytics', 1),
#  ('Junior Specialist - Periscope Advanced Insights Growth Mapping, New Ventures',
#   1),
#  ('Assistant Scientist - Metabolics Division Lead', 1),
#  ('Senior Data Engineer, Next Big Sound', 1),
#  ('Biomedical Engineering: Faculty Position - Open Rank (Asst or Assoc Professor)',
#   1),
#  ('Solutions Consultant', 1),
#  ('Senior Scientist, Immunology', 1),
#  ('A Vigorously-Charged Scientific Programmer', 1),
#  ('Sr. Data Scientist – Market Research', 1),
#  ('Director of Software', 1),
#  ('Certifying Scientist / Quantitation Scientist', 1),
#  ('Sr Manager - Data & Analytics', 1),
#  ('Big Data Engineer (mid to senior level)', 1),
#  ('Data Science - Senior Consultant', 1),
#  ('Adolescent Health Evaluation Specialist', 1),
#  ('Windows Programmer / Software Engineer - Intermediate/Senior -ELSYS -7332',
#   1),
#  ('Team Lead – Informatics. Sensus USA Inc. Atlanta, Georgia', 1),
#  ('Electrical / Substation Design Engineer', 1),
#  ('Windows Programmer / Software Engineer (Advanced Degree) - ELSYS', 1),
#  ('Electrical/Computer Engineer - EOSL', 1),
#  ('Windows Programmer / Software Engineer - Entry/ Intermediate -ELSYS - 7333',
#   1),
#  ('Senior Software Engineer, Machine Learning', 1),
#  ('Staff CAD Technician', 1),
#  ('Engineering Co-op', 1),
#  ('Associate Manager, Agile Paid Media', 1),
#  ('Category Manager', 1),
#  ('FPGA Hardware Researcher - CIPHER', 1),
#  ('Senior Marketing Research Analyst', 1),
#  ('Right-of-Way Acquisition Manager | Atlanta, GA', 1),
#  ('DevOps Engineer - ELSYS', 1),
#  ('Senior Analyst, Payments Study - GC Insights, New Ventures', 1),
#  ('Senior Analyst - Multi-client Benchmarks, GC Insights - New Ventures', 1),
#  ('BI - Analytics - Cloud Platform Operations Analyst', 1),
#  ('Sr Quantitative Finance Analyst/C++ Developer', 1),
#  ('Business Analytics Consultant Sr', 1),
#  ('Various Professional, Technical, Administrative and Scientific positions supporting a Public Health Client',
#   1),
#  ('Senior Engineer II, Packaging Research', 1),
#  ('Pediatrics – Dir. Pediatric Clinical and Translational Research', 1),
#  ('Avionics System Designer - ELSYS', 1),
#  ('Business Development Manager (Southeast Region)', 1),
#  ('Senior Research Analyst and Team Lead - HR Insights - Bersin', 1),
#  ('Landscape Architect (Graduate)', 1),
#  ('Implementation Engineer (Machine Learning/Data Analytics)', 1),
#  ('Post-Doctoral Fellowship Training Program in Cancer Epidemiology, Prevention and Survivorship',
#   1),
#  ('Senior Software Researcher - CIPHER', 1),
#  ('Configuration Management/Quality Assurance Manager -ATAS', 1),
#  ('Practice Technology Regional BIM Manager (East Region)', 1),
#  ('Windows Programmer / Software Engineer- ELSYS', 1),
#  ('Cyber Security Systems Engineer', 1),
#  ('Technical Product Manager – Secureworks – Austin, TX, Atlanta, GA, D.C. Metro, or Remote',
#   1),
#  ('Senior\xa0FPGA\xa0Hardware\xa0Researcher - CIPHER', 1),
#  ('Environmental Project Engineer - CCR/Fly Ash NPDES', 1),
#  ('Technical Lead Data Engineer/Architect', 1),
#  ('Post-Doctoral Fellow- Medical Imaging, Machine Learning and CT Physics', 1),
#  ('Avionics System Designer (Advanced Degree) - ELSYS', 1),
#  ('Branch\xa0Head\xa0for\xa0FPGA\xa0Hardware\xa0Research\xa0and\xa0Development - CIPHER',
#   1),
#  ('Sr. Staff Enterprise Application Engineer', 1),
#  ('Senior Firmware Engineer - ELSYS', 1),
#  ('Senior Staff-National Tax office', 1),
#  ('Senior Analyst - Marketing Research', 1),
#  ('Sr. Product Manager – Secureworks – Austin, TX, Atlanta, GA, D.C. Metro, or Remote',
#   1),
#  ('Senior Web Developer', 1),
#  ('Senior Analyst - GC Insights, New Ventures', 1),
#  ('Assistant Architect', 1),
#  ('Advanced Analytics Consultant - Machine Learning', 1),
#  ('Research Epidemiologist', 1),
#  ('Advanced Data Scientist', 1),
#  ('Account Executive - Healthcare Sales (Atlanta)', 1),
#  ('Data Scientist III', 1),
#  ('Product Manager (Flexible Location)', 1),
#  ('Data Science Solutions Lead(Data Engineer)-PS10274', 1),
#  ('Clinical Research Coordinator/Nurse', 1),
#  ('Computer Network Defense (CND) Analyst', 1),
#  ('Computer Operator/Support Engineer', 1),
#  ('Sr. Manager , Data Science Forecasting', 1),
#  ('Operations Research Analyst (contractor role)', 1),
#  ('Director of Monitoring and Evaluation', 1),
#  ('Post Doctoral Fellow Biochemistry', 1),
#  ('SR DATA ANALYST SUPPLY CHAIN', 1),
#  ('Chronic Disease Portfolio Lead', 1),
#  ('Compensation and HRIS Analyst', 1),
#  ('Director, Customer Analytics', 1),
#  ('Information Systems Security Officer - RSD', 1),
#  ('Data Science - Senior Manager - Atlanta', 1),
#  ('Account Executive - Healthcare Sales', 1),
#  ('Software Engineer - 6943', 1),
#  ('Professional Development Manager - McKinsey Academy, New Ventures', 1),
#  ('Software Researcher - CIPHER', 1),
#  ('Systems Software Engineer', 1),
#  ('Digital Marketing Consultant - Automotive Retail - Atlanta', 1),
#  ('Senior Packaging Engineer I - PET', 1),
#  ('Account Executive Fraud Solutions, Acquiring Eastern Region', 1),
#  ('Junior DevOps Software Engineer – Secureworks – Atlanta, GA, Austin, TX or Remote',
#   1),
#  ('Senior Scientist, Development', 1),
#  ('Research Engineering/ Scientist Associate II - Research Associate, Data Integration Team, Department of Population Health',
#   1),
#  ('GIS Analyst and Research Associate', 1),
#  ('Sr Software Engineer, Applied Machine Learning', 1),
#  ('ML Engineer', 1),
#  ('Product Owner', 1),
#  ('Senior Operations Analyst, Omni', 1),
#  ('GBO Data Scientist - Sr. Advisor', 1),
#  ('Controls and Automation Scientist', 1),
#  ('Billing Call Center Representative', 1),
#  ('Research Engineering/ Scientist Associate IV - Research Engineering Scientist Associate IV, Neurosurgery',
#   1),
#  ('Senior Software Engineer - C++ for Scientific Toolkits & High Performance Algorithms',
#   1),
#  ('Data Analyst - Public Education Data Analysis', 1),
#  ('Software Defined Radio (SDR) FPGA Principal Engineer- Secret Required', 1),
#  ('Senior Software Engineer, CRM', 1),
#  ('Data Scientist 4, Poker', 1),
#  ('System Engineer/ Project Engineer', 1),
#  ('System Engineer/ Project Engineer- TS/SCI Required', 1),
#  ('Laboratory Supervisor / Hematology', 1),
#  ('DPS - LES - Forensic Scientist I-III (Firearms/Toolmarks)', 1),
#  ('Data Scientist / Operations Research Engineer', 1),
#  ('Clinical Data (Data Entry) Operator I', 1),
#  ('Research Scientist (Neuroscience)', 1),
#  ('Sr Data Scientist - Autonomy', 1),
#  ('Jr. Accountant/Bookkeeper', 1),
#  ('Research Analyst In-House Counsel', 1),
#  ('Consultant, Data Scientist', 1),
#  ('Senior Data Scientist -Security & Malware -DeepArmor', 1),
#  ('Data Scientist -Transit', 1),
#  ('Multi-Int Data Scientist', 1),
#  ('Customer Care (Call Center) Specialist', 1),
#  ('Environmental Scientist and Environmental Scientist Sr. (Temporary)', 1),
#  ('Sr Data Scientist - Vision', 1),
#  ('PRINCIPAL DATA SCIENTIST BL LAB', 1),
#  ('Water Resources Planner / Scientist - Water Business', 1),
#  ('Research Scientist (Vision Science)', 1),
#  ('Human Capital Research Scientist', 1),
#  ('AI/ML Scientist', 1),
#  ('Chief Data Scientist Solution Architect - Virtual / Texas Job', 1),
#  ('Scientist, Bioinformatics', 1),
#  ('Medical Research Specialist - Policy Analyst', 1),
#  ('Research Scientist II', 1),
#  ('Engineering Scientist Associate - GNSS Analyst', 1),
#  ('Assistant Cultural Resources Specialist/Historian', 1),
#  ('Medical Lab Scientist (MLS)', 1),
#  ('Document Control Coordinator', 1),
#  ('Senior Data Scientist – IoT Cloud Services', 1),
#  ('Engineering Scientist Associate', 1),
#  ('Quantitative Analyst - Bank Financial Risk', 1),
#  ('Engineering Scientist - GNSS Analyst', 1),
#  ('Research Scientist - Sedimentary Petrographer', 1),
#  ('Bioinformatics Data Programmer', 1),
#  ('Molecular Research and Development Scientist', 1),
#  ('Technical Communications Co-op', 1),
#  ('Machine Learning Compiler Verification', 1),
#  ('Medical Research Specialist - Polcy Analyst', 1),
#  ('Credit Research Analyst', 1),
#  ('Research Engineering/ Scientist Associate I', 1),
#  ('Human Resources Specialist or Human Resources Advisor', 1),
#  ('Engineering Scientist Associate - Software Engineering Associate', 1),
#  ('Scientist III/Staff Scientist IVD Compliance', 1),
#  ('Research Engineering/ Scientist Associate III - Visualization Specialist',
#   1),
#  ('Research Engineering/ Scientist Assistant', 1),
#  ('Customer Care Tier 3 Specialist', 1),
#  ('Compliance Quantitative Data Analyst', 1),
#  ('Account Manager (Austin, TX)', 1),
#  ('Data Analyst Disaster Recovery Implementation', 1),
#  ('Lead Scientist - Machine Learning (58401)', 1),
#  ('Engineering Scientist - Underwater Sensor Perception Algorithm Designer',
#   1),
#  ('Libraries Engineer - Machine Learning', 1),
#  ('Senior Scientist, Data Science Architect', 1),
#  ('Senior Scientist, Research', 1),
#  ('HPC Analytics Research Scientist', 1),
#  ('Sr. Data Scientist/Modeling & Simulation Engineer Expert', 1),
#  ('Associate Account Manager', 1),
#  ('Supervisor, Revenue Cycle Management', 1),
#  ('Engineering Scientist - Digital Signal Processing Scientist', 1),
#  ('Billing System (Xifin) Support Coordinator', 1),
#  ('Senior Data Warehouse Analyst', 1),
#  ('Research Engineering/ Scientist Associate III - TexNet Operations Associate',
#   1),
#  ('Machine Learning Developer – Reinforcement Learning | INZONE.AI', 1),
#  ('Real Estate Services Tech 1', 1),
#  ('Engineering Scientist - R and D User Interface Software Developer', 1),
#  ('PPC Specialist', 1),
#  ('Software Development Principal Engineer – Data Scientist', 1),
#  ('Technical Account Manager (Austin, TX)', 1),
#  ('Sales Operations Leader', 1),
#  ('Air Quality Staff Engineer/Scientist', 1),
#  ('Engineering Scientist Associate - Software Defined Radio Receiver Hardware Developer',
#   1),
#  ('Front End Software Engineer', 1),
#  ('Engineering Scientist - Software Defined Radio Receiver Developer', 1),
#  ('Software Development Engineer, Homepage Personalization Team', 1),
#  ('Junior Web Development Instructor', 1),
#  ('Sr. Engineering Analyst/Sr. Data Engineer', 1),
#  ('Security Specialist', 1),
#  ('Research Engineering/ Scientist Associate IV - Senior Remote Sensing Scientist',
#   1),
#  ('Engineering Scientist - Senior Systems Engineering Scientist', 1),
#  ('Big Data Pipeline Software Engineer - Java/Scala', 1),
#  ('Research Engineering/ Scientist Associate II - Lab Manager', 1),
#  ('Research Scientist (Computer Architecture for Machine Learning)', 1),
#  ('Scientist/Ecologist', 1),
#  ('AI Strategy Consultant - Digital Commerce', 1),
#  ('Mgr, Product Marketing', 1),
#  ('Environmental Geologist', 1),
#  ('Research Engineering/ Scientist Associate II - Research Assistant, Psychiatry',
#   1),
#  ('Senior Director of Big Data Science & Analytics', 1),
#  ('Front-end Developer – AdTech', 1),
#  ('AI Strategy Consultant - Financial Services', 1),
#  ('Research Engineering/ Scientist Assistant - Research Engineering Scientist Assistant',
#   1),
#  ('Data and Analytics Engineer, Python Developer', 1),
#  ('Experienced Stack Testing Technician', 1),
#  ('Director of Product Development', 1),
#  ('Sr. Libraries Engineer - Machine Learning', 1),
#  ('DocTools Architect, Nokia Software', 1),
#  ('Lead Biological Scientist', 1),
#  ('Machine Learning Principal Performance Engineer', 1),
#  ('Sr. SPC (Statistical Process Control) Engineer', 1),
#  ('Cognitive Research Scientist (SME), Cognitive Computing', 1),
#  ('Corporate Compliance Manager', 1),
#  ('Senior Mobile Developer (React Native)', 1),
#  ('Senior Software Engineer II', 1),
#  ('Senior GIS FEMA Production Task Lead', 1),
#  ('Network Security Analyst', 1),
#  ('ISV Technology Director - AI and ML - 67511', 1),
#  ('Software Engineer (QA)', 1),
#  ('Data Scientist - Data Product Development (PhD)', 1),
#  ('Data Scientist - TX', 1),
#  ('Data Scientist-ISD', 1),
#  ('Senior - Data Scientist', 1),
#  ('Data Science Analyst - Strategic Data Solutions', 1),
#  ('QA Lead', 1),
#  ('Director, Product Security - Austin, TX', 1),
#  ('Software Systems Engineer', 1),
#  ('Software Engineer (BS - NG) for 2018', 1),
#  ('Sr. Director of Data Science', 1),
#  ('Sr. Staff Data Software Engineer', 1),
#  ('SOFTWARE ENGINEER II (BLACK LOCUS)', 1),
#  ('CPA - Financial Reporting Research Analyst', 1),
#  ('Associate Director, Revenue Cycle Management', 1),
#  ('Advanced Analytics Consultant', 1),
#  ('Sr. Engineering Manager, Applied Machine Learning', 1),
#  ('Software Engineer (MS – NG) for 2018', 1),
#  ('Engineering Scientist - Senior Software Defined Radio Receiver Software Developer',
#   1),
#  ('SR SOFTWARE ENG - BLACK LOCUS', 1),
#  ('Public Health Policy Research Analyst / Technical Writer', 1),
#  ('Cognitive Software Engineer', 1),
#  ('Manager, Polymer Process Development (Research & Development)', 1),
#  ('Sr. Software/ Platform Engineer', 1),
#  ('Lead Architect, Machine Learning (42821)', 1),
#  ('Water Resources Engineer 5', 1),
#  ('Software Engineer - AI implementation', 1),
#  ('Senior Staff Design Engineer (Machine Learning, 52162)', 1),
#  ('Data Scientist, Austin', 1),
#  ('Junior Data Scientist, Dell HR - Diversity & Inclusion', 1),
#  ('DATA SCIENTIST BL LAB', 1),
#  ('Data Mining Scientist', 1),
#  ('Junior Data Scientist, Dell HR - Talent Acquisition', 1),
#  ('HPC Software Engineer II', 1),
#  ('WRF-Hydro/National Water Model Software Engineer III', 1),
#  ('Machine Learning Engineer - Language Modeling', 1),
#  ('Research Scientist (Emerging Technologies)', 1),
#  ('Senior Engineer - Cryo Systems (664049)', 1),
#  ('Principal Engineer- Mechanical (663909)', 1),
#  ('Manufacturing Planner Senior (663572)', 1),
#  ('Engineer II-Mechanical (663905)', 1),
#  ('Associate Engineer-Industrial Engineering (664154)', 1),
#  ('Technical Specialist I-Mechanical (663397)', 1),
#  ('Engineer Associate - Systems (663794)', 1),
#  ('Associate Engineer - M P (664248)', 1),
#  ('Manufacturing Compliance Specialist II (664084)', 1),
#  ('Product and Market Research Analyst', 1),
#  ('Engineer Senior - Electrical System Integration & Test (663756) - Security Clearance Required',
#   1),
#  ('Project Engineer II - Electronic Systems Integration & Test (659059) - Security clearance required',
#   1),
#  ('Engineer Principal-Electrical Power Systems (662772) - Security clearance required',
#   1),
#  ('Senior Engineer-Spacecraft Bus Lead (662952) - Security clearance required',
#   1),
#  ('Engineer I-Electrical System Integration & Test (663754)- Security Clearance Required',
#   1),
#  ('Data Quality Analyst', 1),
#  ('Senior Engineer - Spacecraft Electrical Systems Engineer (661998)', 1),
#  ('Engineer Principal - Electrical System Integration & Test (663757)', 1),
#  ('Sr. FPGA Verification Engineer', 1),
#  ('Senior Engineer-Electrical System Integration & Test (664233)', 1),
#  ('Electrical Project Engineer II (661667) - Security Clearance Required', 1),
#  ('Principal Engineer-Mission Systems Architect (663394) - Security clearance required',
#   1),
#  ('Senior Engineer-Electrical Power Systems (662760) - Security clearance required',
#   1),
#  ('Project Engineer Senior - Systems Integration & Test (663337) - Security clearance required',
#   1),
#  ('Senior Engineer-Guidance, Navigation & Control (GN C ) - Security Clearance Required (663361)',
#   1),
#  ('Principal Engineer-Electro-Optical Payload Systems (663982) - Security clearance required',
#   1),
#  ('Research Scientist (Vision Technology)', 1),
#  ('Airborne Imaging Spectrometer Calibration Scientist', 1),
#  ('Environmental Scientist III', 1),
#  ('Mesoscale Data Assimilation Scientist', 1),
#  ('CIRES/NSIDC Data Support Specialist', 1),
#  ('Geospace Model Scientist / Scientific Developer', 1),
#  ('Quantitative Business Analyst, Google Technical Services', 1),
#  ('CIRES/SWPC Space Weather Scientist *Closes 7/31/2018', 1),
#  ('Experiments and Modelling Analyst, Google Technical Services', 1),
#  ('Scientist I/II (ADX-69-18)', 1),
#  ('Clinical Scientist, Endpoints and Outcomes', 1),
#  ('Service Desk Specialist I - Field Science and Remote Operations', 1),
#  ('Business Analytics Analyst', 1),
#  ('Scientist I/II - Bioinformatics 2018-132', 1),
#  ('Scientist, Cell Biology, Small Molecule Drug Discovery and New Target ID/Validation',
#   1),
#  ('Digital Analyst / Media Trader', 1),
#  ('Targeted Search-CSD Guest Scientist Research Associate', 1),
#  ('CIRES/ GSD Research Associate: Numerical Weather Prediction Scientist', 1),
#  ('Meteorological Data Systems Programmer/Analyst, RA III', 1),
#  ('Outreach Specialist (664246)', 1),
#  ('Professional Research Asst', 1),
#  ('RESEARCH SCIENTIST - OUTER SOLAR SYSTEM', 1),
#  ('Service Desk Process Specialist - Field Science and Remote Ops', 1),
#  ('IVD Research Associate (ADX-29-18)', 1),
#  ('Director of Corporate Initiatives', 1),
#  ('Engineering Aide I-Configuration & Data Management (663575)', 1),
#  ('PostDoctoral Associate', 1),
#  ('Project Controls Analyst I (664192)', 1),
#  ('Metrology Technician', 1),
#  ('Self Serve Inside Sales Specialist', 1),
#  ('Senior Research Analyst - Energy', 1),
#  ('Database Administrator IV', 1),
#  ('Technical Intern-Optical (664262)', 1),
#  ('Numerical Algorithm Software Engineer', 1),
#  ('Command & Data Handling Section Lead (663677)', 1),
#  ('Senior Scientist - IVD/CDx Assay Development (ADX-67-18)', 1),
#  ('Commodity Specialist II (664207)', 1),
#  ('Senior Scientist - Analytical, Formulation & Stability', 1),
#  ('Post-Doctoral Researcher - Marine Energy Resource Characterization', 1),
#  ('Production Control Center Scheduler (663788)', 1),
#  ('Process Center Technician III (663420)', 1),
#  ('Subcontract Lead (664046)', 1),
#  ('Process Center Technical Specialist II (663759)', 1),
#  ('Staff Software Engineer - R&D', 1),
#  ('Detector Test Associate Engineer (664222)', 1),
#  ('Service Desk Specialist I - Instrument Science/Eng Operations', 1),
#  ('Engineering Assistant II (664051)', 1),
#  ('Engineer I - Cryogenics (663676)', 1),
#  ('Technician III-Metrology (664170)', 1),
#  ('CIRES Director of Human Resources', 1),
#  ('Technician II-Test (661960)', 1),
#  ('Embedded Software Engineer I (664188)', 1),
#  ('LASP MO&DS Division Director', 1),
#  ('Sr Deep Learning Software Engineer', 1),
#  ('Staff Consultant - Optical (661858)', 1),
#  ('Material Planner (664189)', 1),
#  ('Manager-Thermal Vacuum & Climatics (663040)', 1),
#  ('Electronic Technician III (663868)', 1),
#  ('Staff Consultant - Optical (660988) - Current Security Clearance Required',
#   1),
#  ('Senior Technician-Test (661961)', 1),
#  ('Industrial Operations Manager (663748)', 1),
#  ('Manufacturing Chemist - (2nd Shift)', 1),
#  ('Technician III-Test - Program Operations (663408)', 1),
#  ('Receiving Inspector I-Procured Inspection (664125)', 1),
#  ('Manufacturing Planner (663573)', 1),
#  ('Property Administrator II (663995)', 1),
#  ('New Business Development Director-Innovative Solutions (664191)', 1),
#  ('SEM / Metallurgical Lab Engineer I (663349)', 1),
#  ('Technician III-Equipment Maintenance (660636)', 1),
#  ('Associate Engineer-Systems Test (663860)', 1),
#  ('Engineer Associate-Mechanical (663696)', 1),
#  ('QC Inspector IV-Quality Assurance (663357)', 1),
#  ('Engineer I - Detector Engineering (663760)', 1),
#  ('Engineer I-Software Quality Assurance (663959)', 1),
#  ('Associate Engineer - Embedded Software (664075)', 1),
#  ('Technical Specialist I-Test - Program Operations (663438)', 1),
#  ('Algorithm & Analysis Software Engineer II (664172)', 1),
#  ('Supply Chain Management Lead (663937)', 1),
#  ('Optical Technical Specialist I (663388)', 1),
#  ('RF Communications System Staff Consultant (664242) - Security clearance required',
#   1),
#  ('Manufacturing Process Center Technician IV (663787)', 1),
#  ('Cyber Security Professional I (664193)', 1),
#  ('Technical Specialist Associate-Test - Program Operations (663435)', 1),
#  ('Supplier Quality Assurance Engineer I (663736)', 1),
#  ('Manufacturing Principal Planner (663891)', 1),
#  ('Project Engineer I-Manufacturing (663880)', 1),
#  ('Industrial Engineer I (663367)', 1),
#  ('Tech Spec Assoc-Mechanical - (663303)', 1),
#  ('QC Inspector III - CMM & Procured Inspection (661026)', 1),
#  ('Project Engineer I - Mechanical (664132)', 1),
#  ('IT Infrastructure Systems Administrator III', 1),
#  ('Engineer II-Metrology (663033)', 1),
#  ('Mechanical Assembly Production Supervisor (663946)', 1),
#  ('Equipment Maintenance Technician IV - (663302)', 1),
#  ('Telemetry, Tracking, and Command / Communications Project Engineer I (662483)',
#   1),
#  ('Technician IV-Test - Program Operations (663418) Security Clearance Required',
#   1),
#  ('Principal Spacecraft Lead (664011)', 1),
#  ('Spacecraft Communications Subsystem Engineer I (663460)', 1),
#  ('Technical Specialist - Optical Test Lab (663332)', 1),
#  ('Lead Software Engineer', 1),
#  ('Engineer I-Mission Systems Analyst (663514)', 1),
#  ('Engineer II - Space Systems (664072)', 1),
#  ('Engineer II-Thermal (664197) Security Clearance Required', 1),
#  ('Engineer II-Manufacturing (663430)', 1),
#  ('Prototype Machinist - 2nd Shift (664067)', 1),
#  ('Principal Technical Specialist- Mechanical (663887)', 1),
#  ('Engineering Aide III - Mission & Process Analytics (662883)', 1),
#  ('Structural Engineer II (663566)', 1),
#  ('Technical Specialist Associate-Test - Program Operations (663436) Security Clearance Required',
#   1),
#  ('Embedded Software Engineer II - LabVIEW (663924)', 1),
#  ('Engineer I - Configuration Management (663742)', 1),
#  ('Optical Technician III (663385)', 1),
#  ('Information Systems Security Engineer (663060)', 1),
#  ('Technician III-Test - RF System Integration (663409)', 1),
#  ('Senior Material Planner (662343)', 1),
#  ('Technical Specialist Principal-Test - Program Operations (663454)', 1),
#  ('Space Telescope Operations Senior Engineer (664143)', 1),
#  ('Engineer II-Systems Test (663486)', 1),
#  ('Technician II-Test (660965) - Security Clearance Required', 1),
#  ('Senior Technical Specialist-Mechanical (663898)', 1),
#  ('Senior Engineer - Electro-Optical Payload Systems (664057)', 1),
#  ('Senior Electrical Instrument Systems Engineer (660634)', 1),
#  ('Principal Engineer-Electro-Optical Payload Systems (664094)', 1),
#  ('Engineer I-Mission Systems Engineer (Systems Operability) (659949) - Security clearance required',
#   1),
#  ('Spacecraft Requirements & Verification Systems-Senior Engineer (664045)',
#   1),
#  ('Senior Engineer-Mission System Integration (664159)', 1),
#  ('Engineer II-DOORS Administrator (662456) - Security clearance required', 1),
#  ('Senior Engineer-System Allocation and Verification (662816)', 1),
#  ('Mechanical Engineering Manager II-Process & Tools (663725)', 1),
#  ('Spacecraft Engineering Manager II - Business Development Lead (662729)', 1),
#  ('Senior Embedded Software Engineer - LabVIEW (664117)', 1),
#  ('Sr. Satellite Ground Software Engineer (663828)', 1),
#  ('Detector Engineering Systems Engineer (663687)', 1),
#  ('Systems Assurance Reliability Engineer II (661099)', 1),
#  ('Technical Specialist II-Test - Program Operations (663440) Security Clearance Required',
#   1),
#  ('Senior Technical Specialist - Optical (663536)', 1),
#  ('Senior Test Technician (660966) - Security Clearance Required', 1),
#  ('Optical Engineer II (663865)', 1),
#  ('Senior Technical Specialist-Test - Program Operations (663444)', 1),
#  ('Engineer I-Systems Test: Attitude Determination & Control Systems (663459)',
#   1),
#  ('Principal Engineer-Space Systems (662730)', 1),
#  ('Project Engineer II - Mission Assurance Manager (662667)', 1),
#  ('Principal PWB Designer- FULL TIME TEMPORARY (663684)', 1),
#  ('Facilities Electrician-HVAC Maintenance Specialist III (661296)', 1),
#  ('Engineer II-System Allocation & Verification (663537)', 1),
#  ('Sr. Engineer - Detector Engineering (663761)', 1),
#  ('Systems Assurance Parts Engineer II (661777)', 1),
#  ('Senior Engineer - Space Systems (660320)', 1),
#  ('Senior Embedded Software Engineer (664186)', 1),
#  ('Engineering Aide I-Systems Integration & Test Engineering (664232)', 1),
#  ('Staff Consultant-Mission System Integration (663980) - Security clearance required',
#   1),
#  ('Engineer II - Electromagnetic Compliance Engineer (663783)', 1),
#  ('Technical Specialist Principal-Test - Program Operations (663455) Security Clearance Required',
#   1),
#  ('Principal Engineer-Systems Test (663690)', 1),
#  ('Principal Engineer-Space Systems Simulators (663330)', 1),
#  ('Engineer Senior-Software Quality Assurance (663353)', 1),
#  ('Senior Algorithm & Analysis Software Engineer (663685)', 1),
#  ('Satellite Ground Software Engineer II (663854) - Security Clearance Required',
#   1),
#  ('Engineer I-Mission Systems Analyst (662222) - Security clearance required',
#   1),
#  ('Engineer Senior-Manufacturing (663882)', 1),
#  ('Electrical Engineer II-Spacecraft Command & Data Handling (663671) - Security clearance required',
#   1),
#  ('Sr. Optical Engineer (664163)', 1),
#  ('Senior Engineer-Spacecraft Lead (664006)', 1),
#  ('Senior Engineer-Space Systems Simulators (663331)', 1),
#  ('Senior Structural Engineer (663564)', 1),
#  ('Senior Technical Specialist-Test - Program Operations (663446) Security Clearance Required',
#   1),
#  ('Principal Engineer-Space Vehicle Lead (663998)', 1),
#  ('Cyber Security Professional II (661903) - Security clearance required', 1),
#  ('Principal Systems Assurance Reliability Engineer (661774)', 1),
#  ('Principal Systems Assurance Parts Engineer (661776)', 1),
#  ('Principal Systems Assurance Radiation Effects Engineer (661768)', 1),
#  ('Engineer II-Instrument Systems Engineer (663131)', 1),
#  ('Principal Embedded Software Engineer - LabVIEW (664114) Security Clearance Required',
#   1),
#  ('Project Engineer II-Mechanical, New Business Lead (663390)', 1),
#  ('Detector Engineering Systems Engineer (663686) - Security Clearance Required',
#   1),
#  ('Telemetry Tracking & Command/Communications Project Engineer II (662650) - Security clearance requir',
#   1),
#  ('Spacecraft Systems Engineer II (662929) - Security clearance required', 1),
#  ('Telemetry, Tracking & Command/Command & Data Handling Subsystem Senior Engineer (662726) - Security',
#   1),
#  ('Principal Engineer-Mission System Integration (664158)', 1),
#  ('Spacecraft Requirements & Verification Systems-Principal Engineer (664043)',
#   1),
#  ('Senior System Safety Engineer (663665)', 1),
#  ('Senior Electrical Engineer-Spacecraft Command & Data Handling (663675) - Security clearance required',
#   1),
#  ('Electrical Engineer II - Analog and Power Supply Design (662638)', 1),
#  ('Senior Spacecraft Structures Design Engineer (661398) - Current Security Clearance Required',
#   1),
#  ('Research Engineer: UI / Frontend Developer', 1),
#  ('Senior Structural Engineer - Electronics (662505)', 1),
#  ('Engineer I-Electrical System Integration & Test (663878)', 1),
#  ('Engineer II-System Allocation & Verification (663538) - Security Clearance Required',
#   1),
#  ('Senior Engineer-Thermal (663471) Security Clearance Required', 1),
#  ('Principal Engineer - Space Systems (662797) - Security Clearance Required',
#   1),
#  ('Engineer II-Guidance, Navigation & Control (GN C ) - Security Clearance Required (663366)',
#   1),
#  ('Project Engineer I - Systems Integration & Test (661529) - Security clearance required',
#   1),
#  ('Principal Engineer-Space Vehicle Lead (664058) - Security Clearance Required',
#   1),
#  ...]

# %%
# bar graph of values for the variable
# fig = plt.figure()
# ax = fig.add_axes([0,0,1,1])
# x = data[slice(None),slice(1)]
# y = data[slice(None),slice(2)]
# ax.bar(x,y)
# plt.show()

# %%
# help(set())

# %%
# D. Visual exploration
# plt.clf
# plt.plot(kind='scatter',x=)

# %%
def job_classification (position):
    """
    This function classifies the job position by looking for keywords in the job title.
    """
    if ('analyst' in position.lower()) :
        job_class = 'Data Analyst'
    elif ('enginneer' in position.lower()) :
        job_class = 'Data Enginneer'
    elif ('scientist' in  position.lower()) :
        job_class = 'Data Scientist'
    else :
        job_class = 'TBD'
    return job_class

# raw_data['job_class'] = raw_data.apply(job_classification(raw_data['position']))

# %% [markdown]
# I'll need to create parse the job description to create a list of qualifications to advance on the position classification.
